# %% [markdown]
# <a href="https://colab.research.google.com/github/bgsgp/kei/blob/main/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **main**

# %% [markdown]
# 挂载 Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 解压数据

# %%
# !cp /content/drive/MyDrive/kei/output.zip /content/output.zip
# !unzip -o /content/output.zip -d /content/
# Out:
# Archive:  /content/output.zip
#    creating: /content/output/
#    creating: /content/output/asr_opt/
#   inflating: /content/output/asr_opt/slicer_opt.list
#    creating: /content/output/slicer_opt/
#   inflating: /content/output/slicer_opt/merged.wav_0000000000_0000170560.wav
#   inflating: /content/output/slicer_opt/merged.wav_0000170560_0000362880.wav
#   inflating: /content/output/slicer_opt/merged.wav_0000362880_0000555200.wav
#   inflating: /content/output/slicer_opt/merged.wav_0000555200_0000798720.wav
#   inflating: /content/output/slicer_opt/merged.wav_0000814720_0001004160.wav
#   inflating: /content/output/slicer_opt/merged.wav_0001030400_0001261120.wav
#   inflating: /content/output/slicer_opt/merged.wav_0001280960_0001430080.wav
#   inflating: /content/output/slicer_opt/merged.wav_0001461760_0001663360.wav
#   inflating: /content/output/slicer_opt/merged.wav_0001663360_0001767680.wav
#   inflating: /content/output/slicer_opt/merged.wav_0001780480_0001965760.wav
# ...

# %% [markdown]
# 安装系统依赖（避开 GraalPy 坑）

# %%
# 修复 psutil（二进制安装避免编译）
# !pip install -q psutil --only-binary=:all:
# 其他必要库
# !pip install -q ffmpeg-python gradio
# 安装 PyTorch（CUDA 12.1）
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %% [markdown]
# 克隆 GPT-SoVITS 并下载预训练模型

# %%
# 克隆仓库
# !git clone https://github.com/RVC-Boss/GPT-SoVITS.git /content/GPT-SoVITS
# 下载预训练模型（约 4.25GB，需要几分钟）
# !cd /content/GPT-SoVITS && git lfs install && git clone https://huggingface.co/lj1995/GPT-SoVITS temp_models
# !cp -r /content/GPT-SoVITS/temp_models/* /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/
# Out:
# Cloning into '/content/GPT-SoVITS'...
# remote: Enumerating objects: 5914, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 5914 (delta 40), reused 14 (delta 14), pack-reused 5849 (from 4)
# Receiving objects: 100% (5914/5914), 14.18 MiB | 14.18 MiB/s, done.
# Resolving deltas: 100% (3369/3369), done.
# Updated git hooks.
# Git LFS initialized.
# Cloning into 'temp_models'...
# remote: Enumerating objects: 69, done.
# remote: Total 69 (delta 0), reused 0 (delta 0), pack-reused 69 (from 1)
# Receiving objects: 100% (69/69), 115.56 KiB | 1.26 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Filtering content: 100% (19/19), 4.93 GiB | 45.78 MiB/s, done.

# %% [markdown]
# 确认环境正常

# %%
# !python -c "import torch; print('Torch OK', torch.cuda.is_available())"
# !python -c "import psutil; print('psutil OK')"
# !python -c "import gradio; print('gradio OK')"
# Out:
# Torch OK True
# psutil OK
# gradio OK

# %% [markdown]
# 启动 WebUI

# %%
# !export is_share=True && python /content/GPT-SoVITS/webui.py
# Out:
# ...
#     GPT_SoVITS/pretrained_models/v2Pro/s2Gv2Pro.pth
#     GPT_SoVITS/pretrained_models/v2Pro/s2Dv2Pro.pth
#     GPT_SoVITS/pretrained_models/s1v3.ckpt
#     GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
#     GPT_SoVITS/pretrained_models/chinese-hubert-base
# /usr/bin/python3: can't open file '/content/GPT_SoVITS/download.py': [Errno 2] No such file or directory
# * Running on local URL:  http://0.0.0.0:9874
# * Running on public URL: https://57b741a2f8d7fea4c5.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
